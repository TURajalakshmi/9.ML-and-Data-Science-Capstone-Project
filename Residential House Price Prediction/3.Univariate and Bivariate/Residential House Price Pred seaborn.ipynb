# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from Visualization import visualization

# %%
dataset = pd.read_csv("house_price_cleaned.csv")
dataset
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0   8450.0   Pave   NaN      Reg
# 1        2          20       RL         80.0   9600.0   Pave   NaN      Reg
# 2        3          60       RL         68.0  11250.0   Pave   NaN      IR1
# 3        4          70       RL         60.0   9550.0   Pave   NaN      IR1
# 4        5          60       RL         84.0  14260.0   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0   7917.0   Pave   NaN      Reg
# 1456  1457          20       RL         85.0  13175.0   Pave   NaN      Reg
# 1457  1458          70       RL         66.0   9042.0   Pave   NaN      Reg
# 1458  1459          20       RL         68.0   9717.0   Pave   NaN      Reg
# 1459  1460          20       RL         75.0   9937.0   Pave   NaN      Reg
#
# ...

# %% [markdown]
# ### Univariate

# %%
visualization.Histogram(dataset, "SalePrice")

# %%
visualization.BoxPlot(dataset, "SalePrice")

# %%
visualization.CountPlot(dataset, "OverallQual")

# %%
visualization.DistPlot(dataset, "LotArea")

# %% [markdown]
# #### Bivariate

# %%
visualization.PairPlot(dataset,["SalePrice","GrLivArea","OverallQual","GarageArea","TotalBsmtSF"])

# %%
visualization.Scatter(dataset,"GarageArea","SalePrice")

# %%
visualization.Heatmap(dataset)

# %%
visualization.JointPlot(dataset,"GrLivArea","SalePrice")
